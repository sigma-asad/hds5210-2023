# %% [markdown]
# <a href="https://colab.research.google.com/github/sigma-asad/hds5210-2023/blob/main/week13_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 13 Review Assignmnet
#
# For the questions below, we're going to refer exclusively to an HHCAPS survey data set that is available in `/data/hhcaps.csv`.  Use whatever commands you want to calculate the information required to get to the answer.  Then, enter your answer in the answers cell as usual.
#
# **NOTE: Enter your answers as string values (inside quotation marks "") even if the answer is actually numeric.**
#
# ---
# ---

# %%
# %matplotlib inline
import pandas as pd

hhcaps = pd.read_csv('https://hds5210-data.s3.amazonaws.com/hhcaps.csv')

# %% [markdown]
# ## #01 -
#
# How many columns does this file contain?

# %%
# Write some code to figure it out
column_count = len(hhcaps.columns)

# %%
column_count
# Out:
# 39

# %%
from numpy import int64

# %%
column_count = int64(column_count)

# %%
answers={}
answers['40.1'] = "39"

# %% [markdown]
# ## #02 -
#
# How many different values for State are there in this file?

# %%
# Write some code to figure it out
hhcaps.groupby(by = ["State"])["Address"].count().reset_index().shape
# Out:
# (55, 2)

# %%
answers['40.2'] = "55"

# %% [markdown]
# ## #03 -
#
# Which of those State values has the highest frequency of occurence?

# %%
hhcaps.head(1).T
# Out:
#                                                                                                     0
# State                                                                                              AL
# CMS Certification Number (CCN)*                                                                 17000
# Provider Name                                       BUREAU OF HOME & COMMUNITY SERVICES           ...
# Address                                             201 MONROE STREET, THE RSA TOWER,  SUITE 1200 ...
# City                                                                             MONTGOMERY
# Zip                                                                                             36104
# Phone                                                                                      3342065341
# Type of Ownership                                                              Official Health Agency
# Offers Nursing Care Services                                                                     True
# Offers Physical Therapy Services                                                                 True
# Offers Occupational Therapy Services                                                             True
# Offers Speech Pathology Services                                                                 True
# Offers Medical Social Services                                                                   True
# Offers Home Health Aide Services                                                                 True
# Date Certified                                                                    1966-07-01 00:00:00
# HHCAHPS Survey Summary Star Rating                                                                NaN
# Footnote HHCAHPS Survey Summary Star Rating          No survey results are available for this period.
# Star Rating for health team gave care in a prof...                                                NaN
# Footnote for Star Rating for gave care in a pro...   No survey results are available for this period.
# Percent of patients who reported that their hom...                                      Not Available
# Footnote for percent of patients who reported t...   No survey results are available for this period.
# Star Rating for health team communicated well w...                                                NaN
# Footnote for Star Rating for communicated well ...   No survey results are available for this period.
# Percent of patients who reported that their hom...                                      Not Available
# Footnote for percent of patients who reported t...   No survey results are available for this period.
# Star Rating team discussed medicines, pain, and...                                                NaN
# Footnote Star Rating discussed medicines, pain,...   No survey results are available for this period.
# Percent of patients who reported that their hom...                                      Not Available
# Footnote for percent of patients who reported t...   No survey results are available for this period.
# Star Rating for how patients rated overall care...                                                NaN
# Footnote for Star Rating for overall care from ...   No survey results are available for this period.
# Percent of patients who gave their home health ...                                      Not Available
# Footnote for percent of patients who gave their...   No survey results are available for this period.
# Percent of patients who reported YES, they woul...                                      Not Available
# Footnote for percent of patients who reported Y...   No survey results are available for this period.
# Number of completed Surveys                                                             Not Available
# Footnote for number of completed surveys             No survey results are available for this period.
# Response rate                                                                           Not Available
# Footnote for response rate                           No survey results are available for this period.

# %%
# Write some code to figure it out
g_df = hhcaps.groupby(by = ["State"])["Address"].count().reset_index()
g_df[g_df["Address"]== g_df["Address"].max()]
# Out:
#    State  Address
# 46    TX     2518

# %%
answers['40.3'] = "TX"

# %% [markdown]
# ## #04 -
#
# Which of those State values has the best average performance on the `Star Rating for health team communicated well with them` score?

# %%
# Write some code to figure it out
g_df = hhcaps.groupby(by = ["State"])["Star Rating for health team communicated well with them"].mean().reset_index()
g_df[g_df["Star Rating for health team communicated well with them"]== g_df["Star Rating for health team communicated well with them"].max()]
# Out:
#    State  Star Rating for health team communicated well with them
# 22    ME                                               4.65

# %%
answers['40.4'] = "ME"

# %% [markdown]
# ## #05 -
#
# What was the average score on `Star Rating for how patients rated overall care from agency` for providers listed as having a `Type of Ownership` of `Hospital Based Program`
#
# **NOTE: Enter your answer with two decimal precision: 0.00**

# %%
# Write some code to figure it out
g_df = hhcaps.groupby(by = ["Type of Ownership"])["Star Rating for how patients rated overall care from agency"].mean().reset_index()
g_df
# Out:
#                         Type of Ownership  \
# 0        Combination Government Voluntary
# 1                  Hospital Based Program
# 2                                   Local
# 3                  Official Health Agency
# 4   Rehabilitation Facility Based Program
# 5  Skilled Nursing Facility Based Program
# 6              Visiting Nurse Association
#
#    Star Rating for how patients rated overall care from agency
# 0                                           3.666667
# 1                                           3.692521
# 2                                           3.159980
# 3                                           3.247588
# 4                                           4.000000
# 5                                           2.680000
# 6                                           3.200924

# %%
answers['40.5'] = "3.69"

# %% [markdown]
# ---
#
# Checking Your Work
# ---
#
# After completing your work above and running each cell, you can check your answers by running the code below.
#
# The easiest way to do this is to use the `Kernel` -> `Restart Kernel and Run All Cells` menu option. This option restarts Python and runs every cell from top to bottom until it encounters an exception of some kind.  It will stop after running the cell below and outputing a summary of how many answers you have correct or incorrect.

# %%
# !pip install boto3
import httpimport
with httpimport.remote_repo('https://gist.githubusercontent.com/paulboal/f14bead2d24fcb9499f4de4607908824/raw/4c3c0e75ea1510bb090bada047372954160e64d4'):
    import checker

checker.check_hds5210(answers, 'week13')
# Out:
# Collecting boto3
#   Downloading boto3-1.33.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 1.7 MB/s eta 0:00:00
# Collecting botocore<1.34.0,>=1.33.0 (from boto3)
#   Downloading botocore-1.33.0-py3-none-any.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 71.1 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.9.0,>=0.8.0 (from boto3)
#   Downloading s3transfer-0.8.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.34.0,>=1.33.0->boto3) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.34.0,>=1.33.0->boto3) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.0,>=1.33.0->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.33.0 botocore-1.33.0 jmespath-1.0.1 s3transfer-0.8.0
# =============================================
# == RESULTS for asadhk1994@gmail.com
# =============================================
#    Q#               Yours  Correct?
#  40.1                  39        OK
#  40.2                  55        OK
#  40.3                  TX        OK
#  40.4                  ME        OK
#  40.5                3.69        OK

# %% [markdown]
# ---
#
# ## Check your work above
#
# If you didn't get them all correct, take a few minutes to think through those that aren't correct.
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to save this notebook file back to GitHub.  To do that in Google Colab:
# 1. File -> Save a Copy in GitHub
# 2. Make sure your HDS5210 repository is selected
# 3. Make sure the file name includes the week number like this: `week02/week02_assignment_1.ipynb`
# 4. Add a commit message that means something
#
# **Be sure week names are lowercase and use a two digit week number!!**
#
# **Be sure you use the same file name provided by the instructor!!**
